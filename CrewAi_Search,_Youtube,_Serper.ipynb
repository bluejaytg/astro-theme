# %% [markdown]
# <a href="https://colab.research.google.com/github/bluejaytg/astro-theme/blob/main/CrewAi_Search%2C_Youtube%2C_Serper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Clone The repository below

# %%
# !git clone https://github.com/hectorpine/CrewAI-HiringVideoEditor-2.git
# Out:
# fatal: destination path 'CrewAI-HiringVideoEditor-2' already exists and is not an empty directory.

# %% [markdown]
# 2. Click Refresh in the left Folder Icon
#
# 3. Click the "CrewAI-HiringVideoEditor-2" Folder
#
# 4. Right Click folder and click "Add New File"
#
# 5. Name file "env"
#
# 6. Add your Serper.dev and Open AI API Keys
#
# 7. Rename your file ".env"
#
# 7. Install the rest of the libraries and dependencies below

# %%
# !curl -sSL https://install.python-poetry.org | python3 -
# Out:
# Retrieving Poetry metadata
#
# The latest version (1.8.2) is already installed.

# %%
import os
os.environ['PATH'] += ":/root/.local/bin"

# %%
cd CrewAI-HiringVideoEditor-2/
# Out:
# /content/CrewAI-HiringVideoEditor-2/CrewAI-HiringVideoEditor-2

# %%
# !poetry install --no-root
# Out:
# Creating virtualenv crewai-zw8I-qz_-py3.10 in /root/.cache/pypoetry/virtualenvs
# Updating dependencies
# Resolving dependencies... (28.5s)
#
# Package operations: 213 installs, 0 updates, 0 removals
#
#   - Installing pyasn1 (0.6.0): Pending...
#   - Installing typing-extensions (4.11.0): Pending...
#   - Installing wrapt (1.16.0): Pending...
#   - Installing zipp (3.18.1): Pending...
#   - Installing zipp (3.18.1): Pending...
#   - Installing wrapt (1.16.0): Installing...
#   - Installing zipp (3.18.1): Pending...
#   - Installing zipp (3.18.1): Pending...
#   - Installing wrapt (1.16.0)
#   - Installing zipp (3.18.1): Pending...
#   - Installing zipp (3.18.1): Installing...
#   - Installing zipp (3.18.1)
#   - Installing typing-extensions (4.11.0): Pending...
#   - Installing wrapt (1.16.0)
#   - Installing zipp (3.18.1)
#   - Installing pyasn1 (0.6.0): Installing...
#   - Installing typing-extensions (4.11.0): Pending...
#   - Installing wrapt (1.16.0)
# ...

# %%
# !pip install crewAI

# %%
# !pip install python-decouple

# %%
# !pip install crewai_tools

# %%
# !python main.py
